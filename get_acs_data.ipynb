# %%
import requests
import json
import pandas as pd
import geopandas as gpd
import os
from dotenv import load_dotenv
from tqdm import tqdm

# %% [markdown]
# ## Identify the variables to call from the ACS

# %% [markdown]
# ### All Possible ACS Vars

# %%
## get a list of all the possible variables

url = "https://api.census.gov/data/2018/acs/acs5/variables.json"

response = requests.get(url)
variables_data = response.json()

variables_list = []

for variable, info in variables_data['variables'].items():
    variables_list.append({
        'Variable': variable,
        'Label': info.get('label', ''),
        'Concept': info.get('concept', ''),
        'Group': info.get('group', '')
    })

# Convert the list of dictionaries into a DataFrame
acs_all_variables = pd.DataFrame(variables_list)

# %%
# save for future reference without calling api again

# acs_all_variables.to_csv("./data/acs/variables/acs5_2018_all_vars.csv", index=False)

# %% [markdown]
# ### Manually Compiled Vars

# %%
# load csv with my manually compiled variables (probably with errors)
variables = pd.read_csv("./data/acs/variables/compiled_acs_vars.csv",usecols=["Variable Code"])

# %% [markdown]
# ### Merge
# Merge the complete variable list with my manually compiled one to get all the details directly from the census and identify errors

# %%
merged_variables = pd.merge(variables, acs_all_variables, how="left", left_on="Variable Code", right_on="Variable")

merged_variables
# Out:
#     Variable Code     Variable  \
# 0     B03002_003E  B03002_003E
# 1     B01001_002E  B01001_002E
# 2     B01001_003E  B01001_003E
# 3     B19013_001E  B19013_001E
# 4     B17001_002E  B17001_002E
# ..            ...          ...
# 310   B25083_001E  B25083_001E
# 311   B25084_001E          NaN
# 312   B25086_001E  B25086_001E
# 313   B25087_001E  B25087_001E
# 314   B25088_001E  B25088_001E
#
#                                                  Label  \
# 0    Estimate!!Total!!Not Hispanic or Latino!!White...
# 1                                Estimate!!Total!!Male
# 2                 Estimate!!Total!!Male!!Under 5 years
# 3    Estimate!!Median household income in the past ...
# 4    Estimate!!Total!!Income in the past 12 months ...
# ..                                                 ...
# 310                   Estimate!!Median value (dollars)
# 311                                                NaN
# 312          Estimate!!Aggregate price asked (dollars)
# 313                                    Estimate!!Total
# 314  Estimate!!Median selected monthly owner costs ...
#
#                                                Concept   Group
# 0                    HISPANIC OR LATINO ORIGIN BY RACE  B03002
# 1                                           SEX BY AGE  B01001
# 2                                           SEX BY AGE  B01001
# 3    MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS ...  B19013
# 4    POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY...  B17001
# ..                                                 ...     ...
# 310            MEDIAN VALUE (DOLLARS) FOR MOBILE HOMES  B25083
# 311                                                NaN     NaN
# 312                    AGGREGATE PRICE ASKED (DOLLARS)  B25086
# 313   MORTGAGE STATUS AND SELECTED MONTHLY OWNER COSTS  B25087
# 314  MEDIAN SELECTED MONTHLY OWNER COSTS (DOLLARS) ...  B25088
#
# [315 rows x 5 columns]

# %%
# drop incorrect variables 
merged_variables = merged_variables.dropna(subset=["Variable"])
# drop duplicated variables
merged_variables = merged_variables.drop_duplicates()
# drop duplicate column
merged_variables = merged_variables.drop("Variable Code",axis=1)

# %%
merged_variables
# Out:
#         Variable                                              Label  \
# 0    B03002_003E  Estimate!!Total!!Not Hispanic or Latino!!White...
# 1    B01001_002E                              Estimate!!Total!!Male
# 2    B01001_003E               Estimate!!Total!!Male!!Under 5 years
# 3    B19013_001E  Estimate!!Median household income in the past ...
# 4    B17001_002E  Estimate!!Total!!Income in the past 12 months ...
# ..           ...                                                ...
# 309  B25082_001E                Estimate!!Aggregate value (dollars)
# 310  B25083_001E                   Estimate!!Median value (dollars)
# 312  B25086_001E          Estimate!!Aggregate price asked (dollars)
# 313  B25087_001E                                    Estimate!!Total
# 314  B25088_001E  Estimate!!Median selected monthly owner costs ...
#
#                                                Concept   Group
# 0                    HISPANIC OR LATINO ORIGIN BY RACE  B03002
# 1                                           SEX BY AGE  B01001
# 2                                           SEX BY AGE  B01001
# 3    MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS ...  B19013
# 4    POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY...  B17001
# ..                                                 ...     ...
# 309       AGGREGATE VALUE (DOLLARS) BY MORTGAGE STATUS  B25082
# 310            MEDIAN VALUE (DOLLARS) FOR MOBILE HOMES  B25083
# 312                    AGGREGATE PRICE ASKED (DOLLARS)  B25086
# 313   MORTGAGE STATUS AND SELECTED MONTHLY OWNER COSTS  B25087
# 314  MEDIAN SELECTED MONTHLY OWNER COSTS (DOLLARS) ...  B25088
#
# [279 rows x 4 columns]

# %%
# save final variable df 

merged_variables.to_csv("./data/acs/variables/acs5_2018_selected_vars.csv", index=False)

# %% [markdown]
# ## Use API to call data for each state

# %%
load_dotenv()

api_key = os.getenv('CENSUS_API')

variable_list = list(merged_variables["Variable"])

# %%
####################################################################################################

def fetch_vars(year, variables, state, api_key):

    url = f"https://api.census.gov/data/{year}/acs/acs5?get={variables}&for=block%20group:*&in=state:{state}%20county:*%20tract:*&key={api_key}"

    try:
        response = requests.get(url)

        if response.status_code == 200:

            print("Response Code 200")
            return response.json()
        
        else:

            print(f"Failed batch request")
            return None
        
    except requests.exceptions.RequestException as e:
        print(f"Request error for {variable}: {e}")
        return None

####################################################################################################

def merge_dataframes(df_list):

    final_df = df_list[0]

    for df in df_list[1:]:

        final_df = pd.merge(final_df, df, on=["state","county","tract","block group"])

    return final_df

####################################################################################################

def make_geoid(df):

    df["GEOID"] = (
        df["state"].str.zfill(2) +
        df["county"].str.zfill(3) +
        df["tract"].str.zfill(6) +
        df["block group"]
    )

# %%
batch_size = 50 
batches = [variable_list[i:i + batch_size] for i in range(0, len(variable_list), batch_size)]

len(batches)
# Out:
# 6

# %%
md_results = []

for batch in tqdm(batches):

    variables = ",".join(batch)

    data = fetch_vars(year=2018, variables=variables, state="24", api_key=api_key)

    if data:
        df_batch = pd.DataFrame(data[1:], columns=data[0])
        md_results.append(df_batch)

    else:
        print("batch failed")
# Out:
#  17%|█▋        | 1/6 [01:20<06:40, 80.03s/it]
# Response Code 200
#  33%|███▎      | 2/6 [02:38<05:17, 79.33s/it]
# Response Code 200
#  50%|█████     | 3/6 [03:59<04:00, 80.10s/it]
# Response Code 200
#  67%|██████▋   | 4/6 [05:17<02:38, 79.22s/it]
# Response Code 200
#  83%|████████▎ | 5/6 [06:38<01:19, 79.65s/it]
# Response Code 200
# 100%|██████████| 6/6 [07:59<00:00, 79.89s/it]
# Response Code 200

# %%
md_final_df = merge_dataframes(md_results)

make_geoid(md_final_df)

# %%
md_final_df.to_csv("./data/acs/acs5_2018_selected_vars_MD.csv",index=False)

# %% [markdown]
# ## Old Test Code

# %%
load_dotenv()

api_key = os.getenv('CENSUS_API')
year = 2023
state = "11"
variables = ",".join(list(variables["Var"]))

url = f"https://api.census.gov/data/{year}/acs/acs5?get={variables}&for=block%20group:*&in=state:{state}%20county:*%20tract:*&key={api_key}"


response = requests.get(url)

response.text
# Out:
# '[["B01001_001E","B03002_003E","B01001_002E","B01001_003E","B19013_001E","B17001_002E","B25003_001E","B25003_002E","B25070_001E","B25064_001E","B25091_001E","B15003_022E","B23025_003E","B23025_004E","B18101_002E","B11009_001E","B16001_002E","state","county","tract","block group"],\n["1181","837","503","35","135708",null,"803","436","367","2590","436","398","745","728",null,null,null,"11","001","000101","1"],\n["1079","979","394","0","156440",null,"771","339","432","3501","339","510","855","855",null,null,null,"11","001","000102","1"],\n["1287","1150","706","91","229199",null,"573","533","40","3501","533","221","697","669",null,null,null,"11","001","000102","2"],\n["690","378","338","12","146250",null,"486","340","146","3284","340","276","408","402",null,null,null,"11","001","000102","3"],\n["0","0","0","0","-666666666",null,"0","0","0","-666666666","0","0","0","0",null,null,null,"11","001","000201","1"],\n["2835","1538","1130","0","-666666666",null,"0","0","0","-666666666","0","0","1082","950",null,null,null,"11","001","000201","2"],\n["785","616","406","13","250001",null,"462","351","111","2266","351","176","512","512",null,null,null,"11","001","000202","1"],\n["662","582","284","39","250001",null,"286","249","37","3501","249","67","327","314",null,null,null,"11","001","000202","2"],\n["843","681","340","8","128457",null,"566","424","142","2492","424","119","570","570",null,null,null,"11","001","000202","3"],\n["1674","1208","819","18","151176",null,"518","316","202","3490","316","204","1068","995",null,null,null,"11","001","000202","4"],\n["1053","812","447","0","174286",null,"502","313","189","2065","313","142","662","662",null,null,null,"11","001","000300","1"],\n["1595","907","766","21","109688",null,"751","209","542","1813","209","491","990","968",null,null,null,"11","001","000300","2"],\n["1719","1087","842","24","250001",null,"653","485","168","3501","485","199","1012","998",null,null,null,"11","001","000300","3"],\n["1302","1077","639","69","201360",null,"524","435","89","3501","435","234","729","729",null,null,null,"11","001","000300","4"],\n["608","443","324","12","250001",null,"235","166","69","3501","166","141","271","257",null,null,null,"11","001","000400","1"],\n["1107","512","494","40","144464",null,"463","215","248","3061","215","181","526","469",null,null,null,"11","001","000400","2"],\n["1272","725","449","29","97386",null,"781","149","632","2155","149","305","956","801",null,null,null,"11","001","000501","1"],\n["928","616","461","21","111513",null,"596","0","596","2404","0","296","581","550",null,null,null,"11","001","000501","2"],\n["1290","683","627","15","117396",null,"843","121","722","2447","121","362","934","912",null,null,null,"11","001","000501","3"],\n["1662","1217","868","195","223833",null,"728","370","358","2042","370","238","1051","1027",null,null,null,"11","001","000502","1"],\n["1786","1113","562","12","140121",null,"1011","592","419","2840","592","339","1140","1118",null,null,null,"11","001","000502","2"],\n["985","670","389","0","117583",null,"605","329","276","1628","329","245","604","567",null,null,null,"11","001","000600","1"],\n["814","728","365","0","250001",null,"378","282","96","1844","282","158","475","475",null,null,null,"11","001","000600","2"],\n["767","656","317","0","103287",null,"495","245","250","1746","245","217","406","372",null,null,null,"11","001","000600","3"],\n["1801","1398","738","0","250001",null,"682","629","53","1849","629","298","1048","1027",null,null,null,"11","001","000600","4"],\n["1167","773","603","14","151298",null,"773","425","348","1853","425","240","863","863",null,null,null,"11","001","000702","1"],\n["1281","551","572","0","51108",null,"873","0","873","1733","0","334","897","897",null,null,null,"11","001","000702","2"],\n["791","450","289","0","95156",null,"536","219","317","2092","219","251","520","489",null,null,null,"11","001","000702","3"],\n["1290","697","683","16","107292",null,"899","208","691","2129","208","298","1051","1030",null,null,null,"1 ...

# %%
test = fetch_var(year=2018, variable='B01001_001E', state="11", api_key=os.getenv('CENSUS_API'))

# %%
df = pd.DataFrame(test[1:], columns=test[0])
df
# Out:
#     B01001_001E state county   tract block group
# 0           857    11    001  006802           1
# 1           623    11    001  002202           3
# 2          1900    11    001  000600           4
# 3          1429    11    001  004201           1
# 4          1805    11    001  001100           1
# ..          ...   ...    ...     ...         ...
# 445        1394    11    001  008802           4
# 446        1968    11    001  007903           1
# 447        3184    11    001  008904           1
# 448         839    11    001  007401           1
# 449        2790    11    001  007403           1
#
# [450 rows x 5 columns]

# %%
data = response.json()

# %%
df = pd.DataFrame(data[1:], columns=data[0])
df
# Out:
#     B01001_001E B03002_003E B01001_002E B01001_003E B19013_001E B17001_002E  \
# 0          1181         837         503          35      135708        None
# 1          1079         979         394           0      156440        None
# 2          1287        1150         706          91      229199        None
# 3           690         378         338          12      146250        None
# 4             0           0           0           0  -666666666        None
# ..          ...         ...         ...         ...         ...         ...
# 566         518         326         248           0       84849        None
# 567        1480         165         742          63      117730        None
# 568        1786         325        1023          89  -666666666        None
# 569        1719          49         859          78       61172        None
# 570          17          17          17           0  -666666666        None
#
#     B25003_001E B25003_002E B25070_001E B25064_001E  ... B15003_022E  \
# 0           803         436         367        2590  ...         398
# 1           771         339         432        3501  ...         510
# 2           573         533          40        3501  ...         221
# 3           486         340         146        3284  ...         276
# 4             0           0           0  -666666666  ...           0
# ..          ...         ...         ...         ...  ...         ...
# 566         392         272         120        2333  ...         172
# 567         449         380          69  -666666666  ...         228
# 568         802         426         376         525  ...         281
# 569         604         261         343  -666666666  ...         175
# 570           5           0           5  -666666666  ...          17
#
#     B23025_003E B23025_004E B18101_002E B11009_001E B16001_002E state county  \
# 0           745         728        None        None        None    11    001
# 1           855         855        None        None        None    11    001
# 2           697         669        None        None        None    11    001
# 3           408         402        None        None        None    11    001
# 4             0           0        None        None        None    11    001
# ..          ...         ...         ...         ...         ...   ...    ...
# 566         443         399        None        None        None    11    001
# 567         838         658        None        None        None    11    001
# 568         813         716        None        None        None    11    001
# 569         684         561        None        None        None    11    001
# 570          17          17        None        None        None    11    001
#
#       tract block group
# 0    000101           1
# 1    000102           1
# 2    000102           2
# 3    000102           3
# 4    000201           1
# ..      ...         ...
# 566  011002           2
# 567  011100           1
# 568  011100           2
# 569  011100           3
# 570  980000           1
#
# [571 rows x 21 columns]

# %%
df["GEOID"] = (
    df["state"].str.zfill(2) +
    df["county"].str.zfill(3) +
    df["tract"].str.zfill(6) +
    df["block group"]
)

# %%
len(df["GEOID"].unique())
# Out:
# 571

# %%
df
# Out:
#                                                   NAME B01003_001E  \
# 0    Block Group 1; Census Tract 1.01; District of ...        1181
# 1    Block Group 1; Census Tract 1.02; District of ...        1079
# 2    Block Group 2; Census Tract 1.02; District of ...        1287
# 3    Block Group 3; Census Tract 1.02; District of ...         690
# 4    Block Group 1; Census Tract 2.01; District of ...           0
# ..                                                 ...         ...
# 566  Block Group 2; Census Tract 110.02; District o...         518
# 567  Block Group 1; Census Tract 111; District of C...        1480
# 568  Block Group 2; Census Tract 111; District of C...        1786
# 569  Block Group 3; Census Tract 111; District of C...        1719
# 570  Block Group 1; Census Tract 9800; District of ...          17
#
#     B01001_001E B06009_006E state county   tract block group         GEOID
# 0          1181        None    11    001  000101           1  110010001011
# 1          1079        None    11    001  000102           1  110010001021
# 2          1287        None    11    001  000102           2  110010001022
# 3           690        None    11    001  000102           3  110010001023
# 4             0        None    11    001  000201           1  110010002011
# ..          ...         ...   ...    ...     ...         ...           ...
# 566         518        None    11    001  011002           2  110010110022
# 567        1480        None    11    001  011100           1  110010111001
# 568        1786        None    11    001  011100           2  110010111002
# 569        1719        None    11    001  011100           3  110010111003
# 570          17        None    11    001  980000           1  110019800001
#
# [571 rows x 9 columns]
